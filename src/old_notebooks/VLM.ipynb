# %%
# %pip install --quiet -U cohere aiohttp asyncio nest_asyncio chromadb google-api-python-client
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 112.9 MB/s eta 0:00:00

# %%
import cohere
import base64
import os
import asyncio
import aiohttp
from IPython.display import Image, display
import json
from datetime import datetime
import logging
from pprint import pprint

# %%
logging.basicConfig(level=logging.DEBUG)

model = "c4ai-aya-vision-32b"
api_key = "gOEjEqKyhxByH6Bjf0quWM1qMHp1nnecLRIELRzX"
temperature = 0.3  # Controls randomness of output. Min: 0.0, Max: 1.0
max_tokens = 200  # Maximum number of tokens to generate in the response.
frequency_penalty = 0.0  # Reduces repetitiveness. Min: 0.0, Max: 1.0
presence_penalty = 0.0    # Similar to frequency_penalty, but applies to all tokens. Min: 0.0, Max: 1.0
top_k = 100  # Top 100 tokens considered for generation.
acceptable_p = 0.80  # Probability mass threshold for token selection. Min: 0.01, Max: 0.99 (default 0.75)
logprobs = True  # Returns log probabilities of generated tokens.

def render_image(image_path):
    """
    Display an image in the notebook with a fixed width.

    Args:
        image_path (str): Path to the image file to display
    """
    display(Image(filename=image_path, width=400))

# %%
# Define parameters for the API call

def generate_text(image_path, message):
    co = cohere.ClientV2(api_key)  # Use Client instead of ClientV2
    with open(image_path, "rb") as img_file:
        base64_image_url = f"data:image/jpeg;base64,{base64.b64encode(img_file.read()).decode('utf-8')}"

    response = co.chat(
        model=model,
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": message},
                    {"type": "image_url", "image_url": {"url": base64_image_url}},  # Corrected structure
                ],
            }
        ],
        temperature=temperature,  # Controls randomness of output
        max_tokens=max_tokens,    # Limits the number of tokens in the output
        frequency_penalty=frequency_penalty,  # Reduces repetitiveness
        presence_penalty=presence_penalty, # Reduces repetitiveness
        k = top_k, # Considers k tokens when selecting the next token
        p = acceptable_p,   # Considers tokens with at least p probability
        logprobs = logprobs # Returns log probabilities of tokens
    )
    print(response.message.content[0].text)

    finish_reason = response.finish_reason
    response_id = response.id
    message_content = response.message.content[0].text
    billed_units = response.usage.billed_units
    tokens = response.usage.tokens

    # Prepare the data to write to a file
    output_data = {
        "billed_tokens_output": getattr(billed_units, 'output_tokens', 0),
        "billed_tokens_input": getattr(billed_units, 'input_tokens', 0),
        "total_tokens_input": getattr(tokens, 'input_tokens', 0),
        "total_tokens_output": getattr(tokens, 'output_tokens', 0),
        "finish_reason": finish_reason,
        "id": response_id,
        "message": message_content,
        "timestamp": datetime.now().astimezone().strftime("%Y-%m-%d %H:%M:%S %Z")  # Add timestamp with time zone
    }

    # Read existing data from the file
    try:
        with open("response_data_8B.json", "r") as file:
            existing_data = json.load(file)
    except (FileNotFoundError, json.JSONDecodeError):
        existing_data = []  # Initialize as an empty list if file doesn't exist or is empty
    existing_data["outputs"].append(output_data)  # Assuming existing_data is a dict with a key "outputs" that holds a list

    # Write the updated data back to the file
    with open("response_data_8B.json", "w") as file:
        json.dump(existing_data, file, indent=4)

    print(output_data)  # Optional: print the output data for verification

# %%
image_path = "./StepFour.png"
render_image(image_path)
# Extract visual entities
logging.basicConfig(level=logging.DEBUG)
message = "Please identify and list all the visual elements, objects, patterns and details you can see in this image."
generate_text(image_path, message)

# %% [markdown]
# ## Evaluate multiple images

# %% [markdown]
# ### code for loading 1 image

# %%
### code for 1 image
image_path = "/content/images/P1_2_10_29_22.jpg"
# show image
# render_image(image_path)

# %% [markdown]
# #### code for loading multiple images

# %%
# folder with images
folder_path = "/content/images"
# List all image files (filter by extension if needed)
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Full paths
image_paths = [os.path.join(folder_path, f) for f in image_files]

# Render the first image
if image_paths:
    display(Image(filename=image_paths[9]))
else:
    print("No images found in the folder.")
image_paths = image_paths[0:9]

# %%
# Initialize Aya's model
# function to generate tags
def generate_text(image_path, message):

    model = "c4ai-aya-vision-32b"
    co = cohere.ClientV2(api_key)

    # convert image to base64 string
    with open(image_path, "rb") as img_file:
        base64_image_url = f"data:image/jpeg;base64,{base64.b64encode(img_file.read()).decode('utf-8')}"

    # systemp message
    system_prompt = """
    Yoy are a highly detailed and visually perceptive expert. Given an image, generate concise yet precise
    set of descriptive tags that accurately capture its key visual elements, including objects, text, colors, and
    any relevant contextual details.

    After generating the tags, carefully verify their accuracy—fabricated or misleading tags are strictly unacceptable.
    Only include details that are visibly present in the image.

    Once verified, construct a single, highly detailed descriptive sentence that incorporates all of the generated tags
    while maintaining clarity, precision, and natural readability. This description serves as guidance for individuals
    with low vision or visual impairments, so be as specific, objective, and unbiased as possible.

    Finally, you must return the output strictly in the following JSON format:

    {{
      "image_description": "highly descriptive sentence",
      "tags": ["<tag1>", "<tag2>", "<tag3>", ...]
    }}
    """

    # invoke the model
    response = co.chat(
        model=model,
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": system_prompt},
                    {"type": "image_url","image_url": {"url": base64_image_url}},
                ],
            }
        ],
        temperature=0.3,
    )

    # extract the text from the response and parse it as JSON
    result_text = response.message.content[0].text.strip()

    # remove triple backticks and possible "json" labels
    if result_text.startswith("```"):
        result_text = result_text.strip("`").strip()
        if result_text.startswith("json"):
            result_text = result_text[len("json"):].strip()

    try:
        image_data = json.loads(result_text)
        return image_data
    except json.JSONDecodeError:
        print("Failed to parse cleaned JSON from Aya output:")
        print(result_text)
        return None

# %% [markdown]
# ### Output 1 image

# %%
### run conversation
output = generate_text(image_path, message=None)
pprint(output)
# Out:
# {'image_description': "A hand holds a box of Zarbee's Baby Natural Grape "
#                       'Flavor Cough Syrup with Immune Support, featuring a '
#                       'cartoon bee character and a purple and yellow color '
#                       'scheme, against a cluttered background with visible '
#                       'carpet and storage bins.',
#  'tags': ['hand',
#           "Zarbee's Baby",
#           'cough syrup',
#           'immune support',
#           'grape flavor',
#           'cartoon bee',
#           'purple',
#           'yellow',
#           'box',
#           'storage bins',
#           'carpet',
#           'cluttered background']}

# %% [markdown]
# ### Output multiple images

# %%
# run conversation for multiple images (0-9)
for image_path in image_paths:
    output = generate_text(image_path, message=None)
    pprint(output)

# %% [markdown]
# ### Pass to ChromaDB

# %%
# %pip install --quiet sentence_transformers
import chromadb
from chromadb.utils import embedding_functions

import cohere
import requests
import base64

co = cohere.ClientV2(api_key="2kw0JObveqo3XK7DwZFdnk13v7IEZ6QKT7y73lgZ")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 5.7 MB/s eta 0:00:00

# %% [markdown]
# # Example creating multimodal embeddings directly with the Cohere API

# %%
import chromadb
from chromadb.utils import embedding_functions

import cohere
import requests
import base64

co = cohere.ClientV2(api_key="2kw0JObveqo3XK7DwZFdnk13v7IEZ6QKT7y73lgZ")

image = requests.get("https://cohere.com/favicon-32x32.png")
stringified_buffer = base64.b64encode(image.content).decode("utf-8")
content_type = image.headers["Content-Type"]
image_base64 = f"data:{content_type};base64,{stringified_buffer}"

response = co.embed(
    model="embed-v4.0",
    input_type="image",
    embedding_types=["float"],
    images=[image_base64],
)

print(response)

# %% [markdown]
# # Example creating embeddings "pure text".
#
# Essentially an array of strings. In our case each one should be a jsonstring object or something like that.

# %%
cohere_ef  = embedding_functions.CohereEmbeddingFunction(
        api_key="2kw0JObveqo3XK7DwZFdnk13v7IEZ6QKT7y73lgZ",
        model_name="multilingual-22-12") #Change model name to more advanced embeddings model or whatever.

multilingual_texts  = [ 'Hello from Cohere!', 'مرحبًا من كوهير!',
        'Hallo von Cohere!', 'Bonjour de Cohere!',
        '¡Hola desde Cohere!', 'Olá do Cohere!',
        'Ciao da Cohere!', '您好，来自 Cohere！',
        'कोहिअर से नमस्ते!'  ]

embeddings = cohere_ef(input=multilingual_texts) # EMbeddings object that can be used

import chromadb
from chromadb.config import Settings

# Optional: persist to disk
client = chromadb.Client(Settings(
    # persist_directory="chroma_db",  # uncomment to enable on-disk persistence
))

# 3) Create a collection (or connect to an existing one)
collection = client.create_collection(
    name="bro",
    embedding_function=cohere_ef
    # If you want Chroma to compute embeddings for you, pass an embedding_function here.
    # But since you already have embeddings, omit embedding_function.
)

# 4) Prepare your data
# Suppose you have:
#   embeddings: a list-of-lists (n_items × dim) or a NumPy array
#   texts:      a list of n_items strings
#   ids:        a list of n_items unique string IDs
#
# e.g.:
# embeddings = [[0.1, -0.2, ...], [0.03, 0.99, ...], ...]
# texts      = ["first document", "second doc", ...]
# ids        = ["doc1", "doc2", ...]
ids = [f"text_{i}" for i in range(len(multilingual_texts))]
# 5) Add to the collection
collection.add(
    ids=ids,
    embeddings=embeddings,
    documents=multilingual_texts,
)

print(f"✅ Added {len(ids)} items to Chroma collection “{collection.name}”.")

# %%
query_texts = ["Hola, ¿cómo estás?"]  # could be any string or list of strings

# 2) (Optional) If you need embeddings first:
query_embeddings = cohere_ef(input=query_texts)  # same Cohere EF you used before

# 3) Run the query by embeddings (you can also use query_texts directly)
results = collection.query(
    query_texts=["Hola"],
    n_results=5,
)

# 4) Inspect the results
print(results)
for idx, doc, dist in zip(results["ids"][0], results["documents"][0], results["distances"][0]):
    print(f"  • id={idx:>6}  distance={dist:.4f}  text={doc}")

# %% [markdown]
# # Setup embeddings function and multimodal chroma collection

# %%
from chromadb.utils.data_loaders import ImageLoader
import chromadb.utils.embedding_functions as embedding_functions
import numpy as np
IMAGE_FOLDER = "/content/images/"
image_loader = ImageLoader()
#embedding_function = CohereEmbeddingFunction(api_key="2kw0JObveqo3XK7DwZFdnk13v7IEZ6QKT7y73lgZ")

multimodal_cohere_ef = embedding_functions.CohereEmbeddingFunction(
    model_name="embed-v4.0",
    api_key="2kw0JObveqo3XK7DwZFdnk13v7IEZ6QKT7y73lgZ",
)

#embeddings_one_image = multimodal_cohere_ef(input=image_paths_array)

client = chromadb.PersistentClient(path="/chroma")

multimodal_collection = client.create_collection(
    name="multimodalReal",
    embedding_function=multimodal_cohere_ef,
    data_loader=image_loader)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-12-5cd9a35833f2> in <cell line: 0>()
#      15 client = chromadb.PersistentClient(path="/chroma")
#      16
# ---> 17 multimodal_collection = client.create_collection(
#      18     name="multimodalReal",
#      19     embedding_function=multimodal_cohere_ef,
#
# /usr/local/lib/python3.11/dist-packages/chromadb/api/client.py in create_collection(self, name, configuration, metadata, embedding_function, data_loader, get_or_create)
#     154             if embedding_function is not None:
#     155                 configuration["embedding_function"] = embedding_function
# --> 156         model = self._server.create_collection(
#     157             name=name,
#     158             metadata=metadata,
#
# /usr/local/lib/python3.11/dist-packages/chromadb/api/rust.py in create_collection(self, name, configuration, metadata, get_or_create, tenant, database)
#     228             configuration_json_str = None
#     229
# --> 230         collection = self.bindings.create_collection(
#     231             name, configuration_json_str, metadata, get_or_create, tenant, database
#     232         )
#
# InternalError: Collection [multimodalReal] already exists

# %% [markdown]
# # Load images to collection

# %%
ids = [f"image_{i}" for i in range(len(image_paths))]
mm_collection = client.get_collection(
    name="multimodalReal",
    embedding_function=multimodal_cohere_ef,
    data_loader=image_loader
)

# add each image individually
for img_id, uri in zip(ids, image_paths):
    mm_collection.add(
        ids=[img_id + uri],
        uris=[uri]
    )
    print(f"Added {img_id} → {uri}")
# Out:
# Added image_0 → images/P10_10_12_16_22.jpg
# Added image_1 → images/P10_11_12_16_22.jpg
# Added image_2 → images/P10_12_12_17_22.jpg
# Added image_3 → images/P10_13_12_17_22.jpg
# Added image_4 → images/P10_14_12_20_22.jpg
# Added image_5 → images/P10_15_12_20_22.jpg
# Added image_6 → images/P10_16_12_20_22.jpg
# Added image_7 → images/P10_17_12_20_22.jpg
# Added image_8 → images/P10_18_12_20_22.jpg
# Added image_9 → images/P10_19_12_20_22.jpg
# Added image_10 → images/P10_20_12_22_22.jpg
# Added image_11 → images/P10_21_12_22_22.jpg
# Added image_12 → images/P10_22_12_22_22.jpg
# Added image_13 → images/P10_23_12_22_22.jpg
# Added image_14 → images/P10_24_12_22_22.jpg
# Added image_15 → images/P10_25_12_22_22.jpg
# Added image_16 → images/P10_26_12_22_22.jpg
# Added image_17 → images/P10_27_12_23_22.jpg
# Added image_18 → images/P10_28_12_23_22.jpg
# Added image_19 → images/P10_29_12_23_22.jpg
# Added image_20 → images/P10_2_12_14_22.jpg
# Added image_21 → images/P10_30_12_23_22.jpg
# Added image_22 → images/P10_31_12_23_22.jpg
# Added image_23 → images/P10_32_12_23_22.jpg
# Added image_24 → images/P10_33_12_23_22.jpg
# Added image_25 → images/P10_34_12_23_22.jpg
# Added image_26 → images/P10_35_12_23_22.jpg
# Added image_27 → images/P10_36_12_28_22.jpg
# Added image_28 → images/P10_37_12_28_22.jpg
# Added image_29 → images/P10_38_12_28_22.jpg
# Added image_30 → images/P10_39_12_28_22.jpg
# Added image_31 → images/P10_3_12_14_22.jpg
# Added image_32 → images/P10_4_12_16_22.jpg
# Added image_33 → images/P10_5_12_16_22.jpg
# Added image_34 → images/P10_6_12_16_22.jpg
# Added image_35 → images/P10_7_12_16_22.jpg
# Added image_36 → images/P10_8_12_16_22.jpg
# Added image_37 → images/P10_9_12_16_22.jpg
# Added image_38 → images/P11_10_12_24_22.jpg
# Added image_39 → images/P11_11_12_26_22.jpg
# Added image_40 → images/P11_12_12_26_22.jpg
# Added image_41 → images/P11_13_12_27_22.jpg
# Added image_42 → images/P11_14_12_27_22.jpg
# Added image_43 → images/P11_15_12_27_22.jpg
# Added image_44 → images/P11_16_12_27_22.jpg
# Added image_45 → images/P11_17_12_27_22.jpg
# Added image_46 → images/P11_18_12_27_22.jpg
# Added image_47 → images/P11_19_12_28_22.jpg
# Added image_48 → images/P11_20_12_28_22.jpg
# Added image_49 → images/P11_21_12_30_22.jpg
# Added image_50 → images/P11_22_12_30_22.jpg
# Added image_51 → images/P11_23_12_30_22.jpg
# Added image_52 → images/P11_2_12_16_22.jpg
# Added image_53 → images/P11_3_12_18_22.jpg
# Added image_54 → images/P11_4_12_19_22.jpg
# Added image_55 → images/P11_5_12_19_22.jpg
# Added image_56 → images/P11_6_12_20_22.jpg
# Added image_57 → images/P11_7_12_22_22.jpg
# Added image_58 → images/P11_8_12_23_22.jpg
# Added image_59 → images/P11_9_12_24_22.jpg
# Added image_60 → images/P12_10_01_20_23.jpg
# Added image_61 → images/P12_11_01_22_23.jpg
# Added image_62 → images/P12_12_01_22_23.jpg
# Added image_63 → images/P12_13_01_22_23.jpg
# Added image_64 → images/P12_14_01_22_23.jpg
# Added image_65 → images/P12_15_01_22_23.jpg
# Added image_66 → images/P12_16_01_23_23.jpg
# Added image_67 → images/P12_18_01_23_23.jpg
# Added image_68 → images/P12_19_01_23_23.jpg
# Added image_69 → images/P12_20_01_23_23.jpg
# Added image_70 → images/P12_21_01_23_23.jpg
# Added image_71 → images/P12_22_01_23_23.jpg
# Added image_72 → images/P12_23_01_23_23.jpg
# Added image_73 → images/P12_2_01_12_23.jpg
# Added image_74 → images/P12_3_01_14_23.jpg
# Added image_75 → images/P12_4_01_14_23.jpg
# Added image_76 → images/P12_5_01_15_23.jpg
# Added image_77 → images/P12_6_01_16_23.jpg
# Added image_78 → images/P12_7_01_20_23.jpg
# Added image_79 → images/P12_8_01_20_23.jpg
# Added image_80 → images/P12_9_01_20_23.jpg
# Added image_81 → images/P13_3_01_16_23.jpg
# Added image_82 → images/P13_6_01_20_23.jpg
# Added image_83 → images/P13_8_01_21_23.jpg
# Added image_84 → images/P13_9_01_23_23.jpg
# Added image_85 → images/P14_10_01_27_23.jpg
# Added image_86 → images/P14_11_01_27_23.jpg
# Added image_87 → images/P14_12_01_27_23.jpg
# Added image_88 → images/P14_13_01_28_23.jpg
# Added image_89 → images/P14_14_01_29_23.jpg
# Added image_90 → images/P14_15_01_29_23.jpg
# Added image_91 → images/P14_16_02_02_23.jpg
# Added image_92 → images/P14_17_02_02_23.jpg
# Added image_93 → images/P14_18_02_04_23.jpg
# Added image_94 → images/P14_19_02_04_23.jpg
# Added image_95 → images/P14_20_02_04_23.jpg
# Added image_96 → images/P14_21_02_04_23.jpg
# Added image_97 → images/P14_2_01_22_23.jpg
# Added image_98 → images/P14_3_01_22_23.jpg
# Added image_99 → images/P14_4_01_23_23.jpg
# Added image_100 → images/P14_5_01_23_23.jpg
# Added image_101 → images/P14_6_01_23_23.jpg
# Added image_102 → images/P14_7_01_24_23.jpg
# Added image_103 → images/P14_8_01_25_23.jpg
# Added image_104 → images/P14_9_01_26_23.jpg
# Added image_105 → images/P15_10_02_18_23.jpg
# Added image_106 → images/P15_11_02_18_23.jpg
# Added image_107 → images/P15_12_02_18_23.jpg
# Added image_108 → images/P15_13_02_19_23.jpg
# Added image_109 → images/P15_14_02_21_23.jpg
# Added image_110 → images/P15_15_02_21_23.jpg
# Added image_111 → images/P15_16_02_22_23.jpg
# Added image_112 → images/P15_17_02_23_23.jpg
# Added image_113 → images/P15_18_02_24_23.jpg
# Added image_114 → images/P15_2_02_12_23.jpg
# Added image_115 → images/P15_3_02_13_23.jpg
# Added image_116 → images/P15_4_02_14_23.jpg
# Added image_117 → images/P15_5_02_15_23.jpg
# Added image_118 → images/P15_6_02_15_23.jpg
# Added image_119 → images/P15_7_02_18_23.jpg
# Added image_120 → images/P15_8_02_18_23.jpg
# Added image_121 → images/P15_9_02_18_23.jpg
# Added image_122 → images/P16_10_03_01_23.jpg
# Added image_123 → images/P16_11_03_03_23.jpg
# Added image_124 → images/P16_12_03_03_23.jpg
# Added image_125 → images/P16_13_03_04_23.jpg
# Added image_126 → images/P16_14_03_07_23.jpg
# Added image_127 → images/P16_15_03_07_23.jpg
# Added image_128 → images/P16_16_03_08_23.jpg
# Added image_129 → images/P16_17_03_08_23.jpg
# Added image_130 → images/P16_18_03_09_23.jpg
# Added image_131 → images/P16_19_03_09_23.jpg
# Added image_132 → images/P16_2_02_24_23.jpg
# Added image_133 → images/P16_3_02_24_23.jpg
# Added image_134 → images/P16_4_02_24_23.jpg
# Added image_135 → images/P16_5_02_27_23.jpg
# Added image_136 → images/P16_6_02_27_23.jpg
# Added image_137 → images/P16_7_02_28_23.jpg
# Added image_138 → images/P16_8_03_01_23.jpg
# Added image_139 → images/P16_9_03_01_23.jpg
# Added image_140 → images/P1_10_11_07_22.jpg
# Added image_141 → images/P1_11_11_10_22.jpg
# Added image_142 → images/P1_12_11_10_22.jpg
# Added image_143 → images/P1_13_11_12_22.jpg
# Added image_144 → images/P1_14_11_12_22.jpg
# Added image_145 → images/P1_15_11_12_22.jpg
# Added image_146 → images/P1_16_11_12_22.jpg
# Added image_147 → images/P1_17_11_14_22.jpg
# Added image_148 → images/P1_18_11_14_22.jpg
# Added image_149 → images/P1_19_11_14_22.jpg
# Added image_150 → images/P1_20_11_14_22.jpg
# Added image_151 → images/P1_21_11_14_22.jpg
# Added image_152 → images/P1_2_10_29_22.jpg
# Added image_153 → images/P1_3_10_29_22.jpg
# Added image_154 → images/P1_4_10_31_22.jpg
# Added image_155 → images/P1_5_10_31_22.jpg
# Added image_156 → images/P1_6_11_01_22.jpg
# Added image_157 → images/P1_7_11_01_22.jpg
# Added image_158 → images/P1_8_11_07_22.jpg
# Added image_159 → images/P1_9_11_07_22.jpg
# Added image_160 → images/P2_10_10_27_22.jpg
# Added image_161 → images/P2_11_10_28_22.jpg
# Added image_162 → images/P2_12_10_28_22.jpg
# Added image_163 → images/P2_13_10_30_22.jpg
# Added image_164 → images/P2_14_10_30_22.jpg
# Added image_165 → images/P2_15_10_30_22.jpg
# Added image_166 → images/P2_16_10_30_22.jpg
# Added image_167 → images/P2_17_10_31_22.jpg
# Added image_168 → images/P2_18_10_31_22.jpg
# Added image_169 → images/P2_19_10_31_22.jpg
# Added image_170 → images/P2_20_10_31_22.jpg
# Added image_171 → images/P2_21_10_31_22.jpg
# Added image_172 → images/P2_22_11_01_22.jpg
# Added image_173 → images/P2_23_11_01_22.jpg
# Added image_174 → images/P2_24_11_01_22.jpg
# Added image_175 → images/P2_25_11_01_22.jpg
# Added image_176 → images/P2_26_11_01_22.jpg
# Added image_177 → images/P2_27_11_01_22.jpg
# Added image_178 → images/P2_28_11_01_22.jpg
# Added image_179 → images/P2_29_11_01_22.jpg
# Added image_180 → images/P2_2_10_18_22.jpg
# Added image_181 → images/P2_30_11_01_22.jpg
# Added image_182 → images/P2_31_11_01_22.jpg
# Added image_183 → images/P2_32_11_01_22.jpg
# Added image_184 → images/P2_3_10_21_22.jpg
# Added image_185 → images/P2_4_10_24_22.jpg
# Added image_186 → images/P2_5_10_24_22.jpg
# Added image_187 → images/P2_6_10_24_22.jpg
# Added image_188 → images/P2_7_10_25_22.jpg
# Added image_189 → images/P2_8_10_27_22.jpg
# Added image_190 → images/P2_9_10_27_22.jpg
# Added image_191 → images/P3_10_11_15_22.jpg
# Added image_192 → images/P3_11_11_15_22.jpg
# Added image_193 → images/P3_12_11_15_22.jpg
# Added image_194 → images/P3_13_11_16_22.jpg
# Added image_195 → images/P3_14_11_16_22.jpg
# Added image_196 → images/P3_15_11_17_22.jpg
# Added image_197 → images/P3_16_11_17_22.jpg
# Added image_198 → images/P3_17_11_17_22.jpg
# Added image_199 → images/P3_18_11_17_22.jpg
# Added image_200 → images/P3_19_11_18_22.jpg
# Added image_201 → images/P3_20_11_18_22.jpg
# Added image_202 → images/P3_21_11_18_22.jpg
# Added image_203 → images/P3_22_11_18_22.jpg
# Added image_204 → images/P3_25_11_21_22.jpg
# Added image_205 → images/P3_26_11_21_22.jpg
# Added image_206 → images/P3_2_11_04_22.jpg
# Added image_207 → images/P3_5_11_07_22.jpg
# Added image_208 → images/P3_6_11_07_22.jpg
# Added image_209 → images/P3_8_11_13_22.jpg
# Added image_210 → images/P3_9_11_14_22.jpg
# Added image_211 → images/P4_11_12_05_22.jpg
# Added image_212 → images/P4_12_12_05_22.jpg
# Added image_213 → images/P4_13_12_05_22.jpg
# Added image_214 → images/P4_14_12_07_22.jpg
# Added image_215 → images/P4_2_11_10_22.jpg
# Added image_216 → images/P4_3_11_12_22.jpg
# Added image_217 → images/P4_4_11_13_22.jpg
# Added image_218 → images/P4_8_11_15_22.jpg
# Added image_219 → images/P5_10_11_19_22.jpg
# Added image_220 → images/P5_11_11_21_22.jpg
# Added image_221 → images/P5_12_11_22_22.jpg
# Added image_222 → images/P5_13_11_22_22.jpg
# Added image_223 → images/P5_14_11_23_22.jpg
# Added image_224 → images/P5_15_11_25_22.jpg
# Added image_225 → images/P5_16_11_25_22.jpg
# Added image_226 → images/P5_17_11_25_22.jpg
# Added image_227 → images/P5_18_11_25_22.jpg
# Added image_228 → images/P5_19_11_25_22.jpg
# Added image_229 → images/P5_20_11_26_22.jpg
# Added image_230 → images/P5_2_11_12_22.jpg
# Added image_231 → images/P5_3_11_14_22.jpg
# Added image_232 → images/P5_4_11_15_22.jpg
# Added image_233 → images/P5_5_11_18_22.jpg
# Added image_234 → images/P5_6_11_18_22.jpg
# Added image_235 → images/P5_7_11_18_22.jpg
# Added image_236 → images/P5_8_11_18_22.jpg
# Added image_237 → images/P5_9_11_18_22.jpg
# Added image_238 → images/P6_10_11_29_22.jpg
# Added image_239 → images/P6_11_12_02_22.jpg
# Added image_240 → images/P6_12_12_02_22.jpg
# Added image_241 → images/P6_13_12_02_22.jpg
# Added image_242 → images/P6_14_12_02_22.jpg
# Added image_243 → images/P6_15_12_02_22.jpg
# Added image_244 → images/P6_16_12_02_22.jpg
# Added image_245 → images/P6_17_12_02_22.jpg
# Added image_246 → images/P6_18_12_02_22.jpg
# Added image_247 → images/P6_19_12_02_22.jpg
# Added image_248 → images/P6_20_12_02_22.jpg
# Added image_249 → images/P6_21_12_02_22.jpg
# Added image_250 → images/P6_22_12_02_22.jpg
# Added image_251 → images/P6_23_12_02_22.jpg
# Added image_252 → images/P6_2_11_17_22.jpg
# Added image_253 → images/P6_4_11_22_22.jpg
# Added image_254 → images/P6_5_11_22_22.jpg
# Added image_255 → images/P6_6_11_29_22.jpg
# Added image_256 → images/P6_7_11_29_22.jpg
# Added image_257 → images/P6_8_11_29_22.jpg
# Added image_258 → images/P6_9_11_29_22.jpg
# Added image_259 → images/P7_10_11_25_22.jpg
# Added image_260 → images/P7_11_11_26_22.jpg
# Added image_261 → images/P7_12_11_26_22.jpg
# Added image_262 → images/P7_13_11_26_22.jpg
# Added image_263 → images/P7_14_11_26_22.jpg
# Added image_264 → images/P7_15_11_26_22.jpg
# Added image_265 → images/P7_16_11_27_22.jpg
# Added image_266 → images/P7_17_11_27_22.jpg
# Added image_267 → images/P7_18_11_27_22.jpg
# Added image_268 → images/P7_19_11_27_22.jpg
# Added image_269 → images/P7_20_11_27_22.jpg
# Added image_270 → images/P7_2_11_14_22.jpg
# Added image_271 → images/P7_3_11_15_22.jpg
# Added image_272 → images/P7_4_11_15_22.jpg
# Added image_273 → images/P7_5_11_16_22.jpg
# Added image_274 → images/P7_6_11_17_22.jpg
# Added image_275 → images/P7_7_11_17_22.jpg
# Added image_276 → images/P7_8_11_20_22.jpg
# Added image_277 → images/P7_9_11_20_22.jpg
# Added image_278 → images/P8_10_12_20_22.jpg
# Added image_279 → images/P8_11_12_20_22.jpg
# Added image_280 → images/P8_12_12_20_22.jpg
# Added image_281 → images/P8_13_12_20_22.jpg
# Added image_282 → images/P8_14_12_20_22.jpg
# Added image_283 → images/P8_15_12_20_22.jpg
# Added image_284 → images/P8_16_12_21_22.jpg
# Added image_285 → images/P8_17_12_22_22.jpg
# Added image_286 → images/P8_18_12_22_22.jpg
# Added image_287 → images/P8_19_12_25_22.jpg
# Added image_288 → images/P8_20_12_25_22.jpg
# Added image_289 → images/P8_2_12_13_22.jpg
# Added image_290 → images/P8_3_12_13_22.jpg
# Added image_291 → images/P8_4_12_14_22.jpg
# Added image_292 → images/P8_5_12_14_22.jpg
# Added image_293 → images/P8_6_12_16_22.jpg
# Added image_294 → images/P8_7_12_16_22.jpg
# Added image_295 → images/P8_8_12_20_22.jpg
# Added image_296 → images/P8_9_12_20_22.jpg
# Added image_297 → images/P9_10_12_25_22.jpg
# Added image_298 → images/P9_11_12_25_22.jpg
# Added image_299 → images/P9_12_12_25_22.jpg
# Added image_300 → images/P9_13_12_26_22.jpg
# Added image_301 → images/P9_14_12_26_22.jpg
# Added image_302 → images/P9_15_12_26_22.jpg
# Added image_303 → images/P9_16_12_26_22.jpg
# Added image_304 → images/P9_17_12_26_22.jpg
# Added image_305 → images/P9_18_01_03_23.jpg
# Added image_306 → images/P9_19_01_03_23.jpg
# Added image_307 → images/P9_20_01_03_23.jpg
# Added image_308 → images/P9_2_12_14_22.jpg
# Added image_309 → images/P9_3_12_22_22.jpg
# Added image_310 → images/P9_4_12_22_22.jpg
# Added image_311 → images/P9_5_12_23_22.jpg
# Added image_312 → images/P9_6_12_23_22.jpg
# Added image_313 → images/P9_7_12_25_22.jpg
# Added image_314 → images/P9_8_12_25_22.jpg
# Added image_315 → images/P9_9_12_25_22.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-a26b17c2d6a9> in <cell line: 0>()
#       8 # add each image individually
#       9 for img_id, uri in zip(ids, image_paths):
# ---> 10     mm_collection.add(
#      11         ids=[img_id + uri],
#      12         uris=[uri]
#
# /usr/local/lib/python3.11/dist-packages/chromadb/api/models/Collection.py in add(self, ids, embeddings, metadatas, documents, images, uris)
#      78         """
#      79
# ---> 80         add_request = self._validate_and_prepare_add_request(
#      81             ids=ids,
#      82             embeddings=embeddings,
#
# /usr/local/lib/python3.11/dist-packages/chromadb/api/models/CollectionCommon.py in wrapper(self, *args, **kwargs)
#      93         def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#      94             try:
# ---> 95                 return func(self, *args, **kwargs)
#      96             except Exception as e:
#      97                 msg = f"{str(e)} in {name}."
#
# /usr/local/lib/python3.11/dist-packages/chromadb/api/models/CollectionCommon.py in _validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     234         if add_records["embeddings"] is None:
#     235             validate_record_set_for_embedding(record_set=add_records)
# --> 236             add_embeddings = self._embed_record_set(record_set=add_records)
#     237         else:
#     238             add_embeddings = add_records["embeddings"]
#
# /usr/local/lib/python3.11/dist-packages/chromadb/api/models/CollectionCommon.py in _embed_record_set(self, record_set, embeddable_fields)
#     553                         )
#     554                     return self._embed(
# --> 555                         input=self._data_loader(uris=cast(URIs, record_set[field]))  # type: ignore[literal-required]
#     556                     )
#     557                 else:
#
# /usr/local/lib/python3.11/dist-packages/chromadb/utils/data_loaders.py in __call__(self, uris)
#      22     def __call__(self, uris: Sequence[Optional[URI]]) -> List[Optional[Image]]:
#      23         with ThreadPoolExecutor(max_workers=self._max_workers) as executor:
# ---> 24             return list(executor.map(self._load_image, uris))
#      25
#      26
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result_iterator()
#     617                     # Careful not to keep a reference to the popped future
#     618                     if timeout is None:
# --> 619                         yield _result_or_cancel(fs.pop())
#     620                     else:
#     621                         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# /usr/lib/python3.11/concurrent/futures/_base.py in _result_or_cancel(***failed resolving arguments***)
#     315     try:
#     316         try:
# --> 317             return fut.result(timeout)
#     318         finally:
#     319             fut.cancel()
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     454                     raise CancelledError()
#     455                 elif self._state == FINISHED:
# --> 456                     return self.__get_result()
#     457                 else:
#     458                     raise TimeoutError()
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/lib/python3.11/concurrent/futures/thread.py in run(self)
#      56
#      57         try:
# ---> 58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#      60             self.future.set_exception(exc)
#
# /usr/local/lib/python3.11/dist-packages/chromadb/utils/data_loaders.py in _load_image(self, uri)
#      18
#      19     def _load_image(self, uri: Optional[URI]) -> Optional[Image]:
# ---> 20         return np.array(self._PILImage.open(uri)) if uri is not None else None
#      21
#      22     def __call__(self, uris: Sequence[Optional[URI]]) -> List[Optional[Image]]:
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3503
#    3504     if filename:
# -> 3505         fp = builtins.open(filename, "rb")
#    3506         exclusive_fp = True
#    3507     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/pn8235-supplemental-material-3.zip'

# %% [markdown]
# # Test Query

# %%
#print(multimodal_collection.peek() )
#print(multimodal_collection.count())
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
import os

query = output['image_description'] + " " + " ".join(output['tags'])

retrieved = mm_collection.query(query_texts=[query], include=['data'], n_results=6)
print(retrieved['ids'])

# Step 1: Extract filenames from retrieved IDs
retrieved_filenames = [id_str.split('/')[-1] for id_str in retrieved['ids'][0]]

# Step 2: Match to full paths
matched_paths = [p for name in retrieved_filenames for p in image_paths if name in p]

# Step 3: Plot with EXIF-corrected orientation
n_images = len(matched_paths)
n_cols = 3
n_rows = (n_images + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))
axes = axes.flatten()

for i, path in enumerate(matched_paths):
    img = Image.open(path)
    img = ImageOps.exif_transpose(img)  # 👈 this line auto-rotates based on EXIF
    axes[i].imshow(img)
    axes[i].set_title(os.path.basename(path), fontsize=10)
    axes[i].axis('off')

# Hide unused subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# [['image_152images/P1_2_10_29_22.jpg', 'image_59images/P11_9_12_24_22.jpg', 'image_51images/P11_23_12_30_22.jpg', 'image_132images/P16_2_02_24_23.jpg', 'image_42images/P11_14_12_27_22.jpg', 'image_307images/P9_20_01_03_23.jpg']]

# %% [markdown]
# # Load Images for Embeddings and create image paths -- KEEP!

# %%
# 0) (Optional) install helpers
# !pip install --quiet requests tqdm

# 1) Authenticate & build Drive service
from google.colab import auth
auth.authenticate_user()  # click link + paste token

from googleapiclient.discovery import build
drive = build('drive', 'v3', cache_discovery=False)

# 2) List every file in the public folder
folder_id = '1JlPUuzTpKrteGsXr8NLmMz1fEXqQlhHo'
files = []
page_token = None
while True:
    resp = drive.files().list(
        q=f"'{folder_id}' in parents and trashed=false",
        spaces='drive',
        fields='nextPageToken, files(id, name)',
        pageToken=page_token
    ).execute()
    files.extend(resp.get('files', []))
    page_token = resp.get('nextPageToken')
    if not page_token:
        break

print(f"Found {len(files)} files.")

# 3) Download in parallel via HTTP
import os, requests
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

output_dir = 'images'
os.makedirs(output_dir, exist_ok=True)

def download_file(f):
    fid, name = f['id'], f['name']
    url = f"https://drive.google.com/uc?export=download&id={fid}"
    out_path = os.path.join(output_dir, name)
    try:
        with requests.get(url, stream=True, timeout=60) as r:
            r.raise_for_status()
            with open(out_path, 'wb') as fh:
                for chunk in r.iter_content(8192):
                    if chunk:
                        fh.write(chunk)
        return True, name
    except Exception as e:
        return False, f"{name} → {e}"

# tweak max_workers up/down depending on your network
with ThreadPoolExecutor(max_workers=8) as ex:
    results = list(tqdm(ex.map(download_file, files), total=len(files)))

# report
success = sum(1 for ok,_ in results if ok)
failures = [msg for ok,msg in results if not ok]
print(f"\n✅ {success} succeeded, {len(failures)} failed.")
if failures:
    print("\nFailures:")
    print("\n".join(failures))

print("CWD:", os.getcwd())            # should be /content
print("Images:", os.listdir("images"))
image_folder = "images"               # relative to /content
image_paths = sorted([
    os.path.join(image_folder, fn)
    for fn in os.listdir(image_folder)
    if os.path.isfile(os.path.join(image_folder, fn))
])
print(image_paths)
# Out:
# Found 317 files.
# 100%|██████████| 317/317 [01:34<00:00,  3.34it/s]
# ✅ 317 succeeded, 0 failed.
# CWD: /content
# Images: ['P7_7_11_17_22.jpg', 'P1_15_11_12_22.jpg', 'P2_20_10_31_22.jpg', 'P8_18_12_22_22.jpg', 'P5_12_11_22_22.jpg', 'P8_10_12_20_22.jpg', 'P2_7_10_25_22.jpg', 'P1_10_11_07_22.jpg', 'P7_17_11_27_22.jpg', 'P15_5_02_15_23.jpg', 'P10_32_12_23_22.jpg', 'P12_10_01_20_23.jpg', 'P2_29_11_01_22.jpg', 'P7_18_11_27_22.jpg', 'P12_15_01_22_23.jpg', 'P4_11_12_05_22.jpg', 'P4_12_12_05_22.jpg', 'P9_2_12_14_22.jpg', 'P15_15_02_21_23.jpg', 'P3_20_11_18_22.jpg', 'P3_19_11_18_22.jpg', 'P12_6_01_16_23.jpg', 'P9_15_12_26_22.jpg', 'P4_4_11_13_22.jpg', 'P8_15_12_20_22.jpg', 'P16_14_03_07_23.jpg', 'P11_18_12_27_22.jpg', 'P1_17_11_14_22.jpg', 'P14_14_01_29_23.jpg', 'P5_7_11_18_22.jpg', 'P15_17_02_23_23.jpg', 'P8_13_12_20_22.jpg', 'P15_4_02_14_23.jpg', 'P9_14_12_26_22.jpg', 'P14_20_02_04_23.jpg', 'P14_19_02_04_23.jpg', 'P10_5_12_16_22.jpg', 'P8_6_12_16_22.jpg', 'P9_18_01_03_23.jpg', 'P10_4_12_16_22.jpg', 'P10_33_12_23_22.jpg', 'P11_6_12_20_22.jpg', 'P3_2_11_04_22.jpg', 'P2_11_10_28_22.jpg', 'P12_20_01_23_23.jpg', 'P15_6_02_15_23.jpg', 'P6_4_11_22_22.jpg', 'P3_16_11_17_22.jpg', 'P14_12_01_27_23.jpg', 'P2_10_10_27_22.jpg', 'P10_19_12_20_22.jpg', 'P6_9_11_29_22.jpg', 'P8_12_12_20_22.jpg', 'P12_4_01_14_23.jpg', 'P10_37_12_28_22.jpg', 'P12_13_01_22_23.jpg', 'P2_26_11_01_22.jpg', 'P1_19_11_14_22.jpg', 'P7_12_11_26_22.jpg', 'P8_14_12_20_22.jpg', 'P6_5_11_22_22.jpg', 'P10_24_12_22_22.jpg', 'P3_21_11_18_22.jpg', 'P5_18_11_25_22.jpg', 'P6_7_11_29_22.jpg', 'P8_17_12_22_22.jpg', 'P10_22_12_22_22.jpg', 'P5_4_11_15_22.jpg', 'P6_21_12_02_22.jpg', 'P16_2_02_24_23.jpg', 'P16_18_03_09_23.jpg', 'P1_11_11_10_22.jpg', 'P5_8_11_18_22.jpg', 'P12_22_01_23_23.jpg', 'P10_21_12_22_22.jpg', 'P9_13_12_26_22.jpg', 'P9_20_01_03_23.jpg', 'P10_6_12_16_22.jpg', 'P10_39_12_28_22.jpg', 'P15_14_02_21_23.jpg', 'P7_15_11_26_22.jpg', 'P16_15_03_07_23.jpg', 'P14_11_01_27_23.jpg', 'P3_15_11_17_22.jpg', 'P9_4_12_22_22.jpg', 'P15_13_02_19_23.jpg', 'P1_3_10_29_22.jpg', 'P5_20_11_26_22.jpg', 'P5_15_11_25_22.jpg', 'P1_21_11_14_22.jpg', 'P3_17_11_17_22.jpg', 'P1_20_11_14_22.jpg', 'P11_3_12_18_22.jpg', 'P8_9_12_20_22.jpg', 'P5_5_11_18_22.jpg', 'P3_18_11_17_22.jpg', 'P2_19_10_31_22.jpg', 'P2_31_11_01_22.jpg', 'P2_17_10_31_22.jpg', 'P12_14_01_22_23.jpg', 'P11_20_12_28_22.jpg', 'P6_19_12_02_22.jpg', 'P14_15_01_29_23.jpg', 'P10_9_12_16_22.jpg', 'P10_14_12_20_22.jpg', 'P12_18_01_23_23.jpg', 'P16_13_03_04_23.jpg', 'P11_23_12_30_22.jpg', 'P9_5_12_23_22.jpg', 'P7_2_11_14_22.jpg', 'P12_11_01_22_23.jpg', 'P14_21_02_04_23.jpg', 'P10_7_12_16_22.jpg', 'P7_20_11_27_22.jpg', 'P14_9_01_26_23.jpg', 'P15_12_02_18_23.jpg', 'P10_20_12_22_22.jpg', 'P1_9_11_07_22.jpg', 'P14_7_01_24_23.jpg', 'P5_6_11_18_22.jpg', 'P6_13_12_02_22.jpg', 'P6_14_12_02_22.jpg', 'P16_7_02_28_23.jpg', 'P2_16_10_30_22.jpg', 'P8_7_12_16_22.jpg', 'P15_2_02_12_23.jpg', 'P16_10_03_01_23.jpg', 'P10_12_12_17_22.jpg', 'P10_23_12_22_22.jpg', 'P11_21_12_30_22.jpg', 'P14_16_02_02_23.jpg', 'P7_10_11_25_22.jpg', 'P3_25_11_21_22.jpg', 'P7_11_11_26_22.jpg', 'P14_4_01_23_23.jpg', 'P4_2_11_10_22.jpg', 'P10_15_12_20_22.jpg', 'P2_27_11_01_22.jpg', 'P5_13_11_22_22.jpg', 'P5_19_11_25_22.jpg', 'P1_5_10_31_22.jpg', 'P11_9_12_24_22.jpg', 'P11_12_12_26_22.jpg', 'P10_3_12_14_22.jpg', 'P8_4_12_14_22.jpg', 'P1_4_10_31_22.jpg', 'P9_7_12_25_22.jpg', 'P3_26_11_21_22.jpg', 'P7_13_11_26_22.jpg', 'P10_13_12_17_22.jpg', 'P4_13_12_05_22.jpg', 'P3_9_11_14_22.jpg', 'P11_4_12_19_22.jpg', 'P2_15_10_30_22.jpg', 'P14_3_01_22_23.jpg', 'P3_13_11_16_22.jpg', 'P14_5_01_23_23.jpg', 'P9_6_12_23_22.jpg', 'P6_6_11_29_22.jpg', 'P1_2_10_29_22.jpg', 'P12_16_01_23_23.jpg', 'P8_5_12_14_22.jpg', 'P11_8_12_23_22.jpg', 'P5_14_11_23_22.jpg', 'P11_16_12_27_22.jpg', 'P1_8_11_07_22.jpg', 'P3_11_11_15_22.jpg', 'P11_13_12_27_22.jpg', 'P10_38_12_28_22.jpg', 'P11_11_12_26_22.jpg', 'P3_22_11_18_22.jpg', 'P14_13_01_28_23.jpg', 'P12_12_01_22_23.jpg', 'P7_16_11_27_22.jpg', 'P16_6_02_27_23.jpg', 'P8_11_12_20_22.jpg', 'P14_10_01_27_23.jpg', 'P3_12_11_15_22.jpg', 'P10_8_12_16_22.jpg', 'P10_18_12_20_22.jpg', 'P2_13_10_ ...
# ['images/P10_10_12_16_22.jpg', 'images/P10_11_12_16_22.jpg', 'images/P10_12_12_17_22.jpg', 'images/P10_13_12_17_22.jpg', 'images/P10_14_12_20_22.jpg', 'images/P10_15_12_20_22.jpg', 'images/P10_16_12_20_22.jpg', 'images/P10_17_12_20_22.jpg', 'images/P10_18_12_20_22.jpg', 'images/P10_19_12_20_22.jpg', 'images/P10_20_12_22_22.jpg', 'images/P10_21_12_22_22.jpg', 'images/P10_22_12_22_22.jpg', 'images/P10_23_12_22_22.jpg', 'images/P10_24_12_22_22.jpg', 'images/P10_25_12_22_22.jpg', 'images/P10_26_12_22_22.jpg', 'images/P10_27_12_23_22.jpg', 'images/P10_28_12_23_22.jpg', 'images/P10_29_12_23_22.jpg', 'images/P10_2_12_14_22.jpg', 'images/P10_30_12_23_22.jpg', 'images/P10_31_12_23_22.jpg', 'images/P10_32_12_23_22.jpg', 'images/P10_33_12_23_22.jpg', 'images/P10_34_12_23_22.jpg', 'images/P10_35_12_23_22.jpg', 'images/P10_36_12_28_22.jpg', 'images/P10_37_12_28_22.jpg', 'images/P10_38_12_28_22.jpg', 'images/P10_39_12_28_22.jpg', 'images/P10_3_12_14_22.jpg', 'images/P10_4_12_16_22.jpg', 'images/P10_5_12_16_22.jpg', 'images/P10_6_12_16_22.jpg', 'images/P10_7_12_16_22.jpg', 'images/P10_8_12_16_22.jpg', 'images/P10_9_12_16_22.jpg', 'images/P11_10_12_24_22.jpg', 'images/P11_11_12_26_22.jpg', 'images/P11_12_12_26_22.jpg', 'images/P11_13_12_27_22.jpg', 'images/P11_14_12_27_22.jpg', 'images/P11_15_12_27_22.jpg', 'images/P11_16_12_27_22.jpg', 'images/P11_17_12_27_22.jpg', 'images/P11_18_12_27_22.jpg', 'images/P11_19_12_28_22.jpg', 'images/P11_20_12_28_22.jpg', 'images/P11_21_12_30_22.jpg', 'images/P11_22_12_30_22.jpg', 'images/P11_23_12_30_22.jpg', 'images/P11_2_12_16_22.jpg', 'images/P11_3_12_18_22.jpg', 'images/P11_4_12_19_22.jpg', 'images/P11_5_12_19_22.jpg', 'images/P11_6_12_20_22.jpg', 'images/P11_7_12_22_22.jpg', 'images/P11_8_12_23_22.jpg', 'images/P11_9_12_24_22.jpg', 'images/P12_10_01_20_23.jpg', 'images/P12_11_01_22_23.jpg', 'images/P12_12_01_22_23.jpg', 'images/P12_13_01_22_23.jpg', 'images/P12_14_01_22_23.jpg', 'images/P12_15_01_22_23.jpg', 'images/P12_16_01_23_23.jpg', 'images/P12_18_01_23_23.jpg', 'images/P12_19_01_23_23.jpg', 'images/P12_20_01_23_23.jpg', 'images/P12_21_01_23_23.jpg', 'images/P12_22_01_23_23.jpg', 'images/P12_23_01_23_23.jpg', 'images/P12_2_01_12_23.jpg', 'images/P12_3_01_14_23.jpg', 'images/P12_4_01_14_23.jpg', 'images/P12_5_01_15_23.jpg', 'images/P12_6_01_16_23.jpg', 'images/P12_7_01_20_23.jpg', 'images/P12_8_01_20_23.jpg', 'images/P12_9_01_20_23.jpg', 'images/P13_3_01_16_23.jpg', 'images/P13_6_01_20_23.jpg', 'images/P13_8_01_21_23.jpg', 'images/P13_9_01_23_23.jpg', 'images/P14_10_01_27_23.jpg', 'images/P14_11_01_27_23.jpg', 'images/P14_12_01_27_23.jpg', 'images/P14_13_01_28_23.jpg', 'images/P14_14_01_29_23.jpg', 'images/P14_15_01_29_23.jpg', 'images/P14_16_02_02_23.jpg', 'images/P14_17_02_02_23.jpg', 'images/P14_18_02_04_23.jpg', 'images/P14_19_02_04_23.jpg', 'images/P14_20_02_04_23.jpg', 'images/P14_21_02_04_23.jpg', 'images/P14_2_01_22_23.jpg', 'images/P14_3_01_22_23.jpg', 'images/P14_4_01_23_23.jpg', 'images/P14_5_01_23_23.jpg', 'images/P14_6_01_23_23.jpg', 'images/P14_7_01_24_23.jpg', 'images/P14_8_01_25_23.jpg', 'images/P14_9_01_26_23.jpg', 'images/P15_10_02_18_23.jpg', 'images/P15_11_02_18_23.jpg', 'images/P15_12_02_18_23.jpg', 'images/P15_13_02_19_23.jpg', 'images/P15_14_02_21_23.jpg', 'images/P15_15_02_21_23.jpg', 'images/P15_16_02_22_23.jpg', 'images/P15_17_02_23_23.jpg', 'images/P15_18_02_24_23.jpg', 'images/P15_2_02_12_23.jpg', 'images/P15_3_02_13_23.jpg', 'images/P15_4_02_14_23.jpg', 'images/P15_5_02_15_23.jpg', 'images/P15_6_02_15_23.jpg', 'images/P15_7_02_18_23.jpg', 'images/P15_8_02_18_23.jpg', 'images/P15_9_02_18_23.jpg', 'images/P16_10_03_01_23.jpg', 'images/P16_11_03_03_23.jpg', 'images/P16_12_03_03_23.jpg', 'images/P16_13_03_04_23.jpg', 'images/P16_14_03_07_23.jpg', 'images/P16_15_03_07_23.jpg', 'images/P16_16_03_08_23.jpg', 'images/P16_17_03_08_23.jpg', 'images/P16_18_03_09_23.jpg', 'images/P16_19_03_09_23.jpg', 'images/P16_2_02_24_23.jpg', 'images/P16_3_02_24_23.jpg', 'images/P16_4_02_24_23.jp ...

# %% [markdown]
# # Images URLs

# %%
from google.colab import auth
from googleapiclient.discovery import build
import numpy as np

# 1) Authenticate & build Drive service
auth.authenticate_user()
drive = build('drive', 'v3', cache_discovery=False)

# 2) List every file in the public folder *including* webContentLink
folder_id = '1JlPUuzTpKrteGsXr8NLmMz1fEXqQlhHo'
files = []
page_token = None
while True:
    resp = drive.files().list(
        q=f"'{folder_id}' in parents and trashed=false",
        spaces='drive',
        # request the direct-download link and the web-view link
        fields='nextPageToken, files(id, name, mimeType, webContentLink, webViewLink)',
        pageToken=page_token
    ).execute()
    files.extend(resp.get('files', []))
    page_token = resp.get('nextPageToken')
    if not page_token:
        break

# 3) Filter to only images (optional) and pull out the links
image_files = [f for f in files if f['mimeType'].startswith('image/')]
download_urls = [f['webContentLink'] for f in image_files]
view_urls     = [f['webViewLink']    for f in image_files]

# 4) (Optional) into NumPy arrays
download_urls_array = download_urls
view_urls_array     = view_urls

print("Download URLs:", download_urls_array)
print("View URLs:    ", view_urls_array)
